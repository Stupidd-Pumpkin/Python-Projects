# %%
import os

import math
def degrees(rad_angle) :
    """Converts any angle in radians to degrees.

    If the input is None, the it returns None.
    For numerical input, the output is mapped to [-180,180]
    """
    if rad_angle is None :
        return None
    angle = rad_angle * 180 / math.pi
    while angle > 180 :
        angle = angle - 360
    while angle < -180 :
        angle = angle + 360
    return angle

def ramachandran_type(residue, next_residue) :
    """Expects Bio.PDB residues, returns ramachandran 'type'

    If this is the last residue in a polypeptide, use None
    for next_residue.

    Return value is a string: "General", "Glycine", "Proline"
    or "Pre-Pro".
    """
    if residue.resname.upper()=="GLY" :
        return "Glycine"
    elif residue.resname.upper()=="PRO" :
        return "Proline"
    elif next_residue is not None \
    and next_residue.resname.upper()=="PRO" :
        #exlcudes those that are Pro or Gly
        return "Pre-Pro"
    else :
        return "General" 

proteins  = ["GLY","ALA","LEU","MET","PHE","TRP","LYS","GLN","GLU","SER","PRO","VAL","ILE","CYS","TYR","HIS","ARG","ASN","ASP","THR"]
initials = ["G","A","L","M","F","W","K","Q","E","S","P","V","I","C","Y","H","R","N","D","T"]
path = 'Train/'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.pdb' in file:
            files.append(os.path.join(r, file))

import Bio.PDB
for f in files:
	pdb_code = f[6:len(f)-4]
	#print(pdb_code)
	structure = Bio.PDB.PDBParser().get_structure(pdb_code, "Train/%s.pdb" % pdb_code)
	output_file = open("Train_csv/%s.csv" % pdb_code,"w")
	for model in structure :
   		for chain in model:
        	 #print ("Chain %s" %str(chain.id))
        	 polypeptides = Bio.PDB.CaPPBuilder().build_peptides(chain)
        	 for poly_index, poly in enumerate(polypeptides) :
            	  phi_psi = poly.get_phi_psi_list()
            	  for res_index, residue in enumerate(poly) :
                	  phi, psi = phi_psi[res_index]
                	  if phi and psi :
                	  #Don't write output when missing an angle
                    	   output_file.write("%s\t%f\t%f\t%s\n" % (initials[proteins.index(residue.resname)],	degrees(phi), degrees(psi),ramachandran_type(residue, poly[res_index+1])))
	output_file.close()
print ("Done")


path = 'Test/'

test_files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.pdb' in file:
            test_files.append(os.path.join(r, file))

import Bio.PDB
for f in test_files:
    pdb_code = f[5:len(f)-4]
    #print(pdb_code)
    structure = Bio.PDB.PDBParser().get_structure(pdb_code, "Test/%s.pdb" % pdb_code)
    output_file = open("Test_csv/%s.csv" % pdb_code,"w")
    for model in structure :
        for chain in model:
            #print ("Chain %s" %str(chain.id))
            polypeptides = Bio.PDB.CaPPBuilder().build_peptides(chain)
            for poly_index, poly in enumerate(polypeptides) :
                phi_psi = poly.get_phi_psi_list()
                for res_index, residue in enumerate(poly) :
                    phi, psi = phi_psi[res_index]
                    if phi and psi :
                        output_file.write("%s\t%f\t%f\t%s\n" % (initials[proteins.index(residue.resname)],	degrees(phi), degrees(psi),ramachandran_type(residue, poly[res_index+1])))
                    else: 
                        output_file.write("%s\t360\t360\txxx\n" % (initials[proteins.index(residue.resname)]))


    output_file.close()
print ("Done")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 5184.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 5280.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 5396.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 5752.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\PDBParser.py:200: PDBConstructionWarning: Negative occupancy in one or more atoms
#   warnings.warn("Negative occupancy in one or more atoms", PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2965.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3010.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3055.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3323.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\PDBParser.py:200: PDBConstructionWarning: Negative occupancy in one or more atoms
#   warnings.warn("Negative occupancy in one or more atoms", PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2936.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2979.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3022.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3263.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2932.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2975.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3018.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3116.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2881.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2924.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2967.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3049.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2880.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2923.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2966.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3056.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\PDBParser.py:200: PDBConstructionWarning: Negative occupancy in one or more atoms
#   warnings.warn("Negative occupancy in one or more atoms", PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2978.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3023.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3068.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3309.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\PDBParser.py:200: PDBConstructionWarning: Negative occupancy in one or more atoms
#   warnings.warn("Negative occupancy in one or more atoms", PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2954.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2999.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3044.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3336.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\PDBParser.py:200: PDBConstructionWarning: Negative occupancy in one or more atoms
#   warnings.warn("Negative occupancy in one or more atoms", PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2857.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2900.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2943.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3192.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2937.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2985.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3033.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3144.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2941.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2989.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3037.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3089.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2899.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2942.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2985.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3058.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2932.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2980.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3028.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3081.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2854.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2897.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2940.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2969.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2961.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3006.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3051.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3100.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2829.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2877.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2925.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3053.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\PDBParser.py:200: PDBConstructionWarning: Negative occupancy in one or more atoms
#   warnings.warn("Negative occupancy in one or more atoms", PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4278.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4323.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4368.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4610.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4242.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4285.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4328.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4604.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4226.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4269.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4312.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4542.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3072.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3120.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3168.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3295.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 5488.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 5576.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 5664.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 6312.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2949.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2997.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3045.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3301.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8262.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 8431.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 8560.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 8739.
#   PDBConstructionWarning)
# Done
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\PDBParser.py:200: PDBConstructionWarning: Negative occupancy in one or more atoms
#   warnings.warn("Negative occupancy in one or more atoms", PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2916.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2959.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3002.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3265.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2967.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3010.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 3053.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3096.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4213.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4256.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4299.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4519.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4244.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4287.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 4330.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 4646.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 10756.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 10799.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 10842.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 10885.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 10928.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 11022.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain C is discontinuous at line 11150.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain D is discontinuous at line 11196.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2862.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2905.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2948.
#   PDBConstructionWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\Bio\PDB\StructureBuilder.py:90: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 3147.
#   PDBConstructionWarning)
# Done
